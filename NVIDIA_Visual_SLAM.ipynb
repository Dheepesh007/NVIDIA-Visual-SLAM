# %%
# SESSION 14 – NVIDIA (Visual SLAM)

# Define previous pose (x, y)
prev_pose = (2, 3)

# Define motion (dx, dy)
motion = (0.4, 0.6)

# Compute new pose
new_pose = (prev_pose[0] + motion[0], prev_pose[1] + motion[1])

# Display results
print("Previous Pose:", prev_pose)
print("Motion:", motion)
print("New Pose:", new_pose)
